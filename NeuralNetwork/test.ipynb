# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
figure_size_width = 10
figure_size_height = 8

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-LAR-62BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-SML-60BPM.xlsx'
file_name3 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\EXTRA\\PROC-EXTRA-BSTEPS-LR-LAR-60BPM.xlsx'

ITERATION_SIZE = 700

df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)
df3 = pd.read_excel(file_name3)

df = df.head(ITERATION_SIZE)
df2 = df2.head(ITERATION_SIZE)
df3 = df3.head(ITERATION_SIZE)

# Get the sensor values from the DataFrame
sensor_values1 = df[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]
sensor_values2 = df2[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]
sensor_values3 = df3[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]

# Create a 2x2 subplot
plt.figure(figsize=(8, 6))

# Loop through each sensor and plot its data from sensor_values1 and sensor_values2
sensors = ['L_Pitch']
for i, sensor in enumerate(sensors, 1):
    plt.subplot(1, 1, i)
    plt.plot(sensor_values1[sensor], label='Large', alpha=0.6)
    plt.plot(sensor_values2[sensor], label='Small', alpha=0.6)
    #plt.plot(sensor_values3[sensor], label='BSTEPS', alpha=0.6)
    plt.xlabel('Iteration')
    plt.ylabel('Rotation Value (Sensor Value)')
    plt.title(f'{sensor} Sensor Data')
    plt.legend()


plt.suptitle('Large vs. Small Step Sensor Data')

# Adjust layout to avoid overlapping titles
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-L-LAR-60BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-L-SML-60BPM.xlsx'
file_name3 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-SML-60BPM.xlsx'

ITERATION_SIZE = 700

df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)

df = df.head(ITERATION_SIZE)
df2 = df2.head(ITERATION_SIZE)

# Get the sensor values from the DataFrame
sensor_values1 = df[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]
sensor_values2 = df2[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]

# Create a 2x2 subplot
plt.figure(figsize=(figure_size_width, figure_size_height))

# Loop through each sensor and plot its data from sensor_values1 and sensor_values2
sensors = ['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']
for i, sensor in enumerate(sensors, 1):
    plt.subplot(2, 2, i)
    plt.plot(sensor_values1[sensor], label='Large', alpha=0.6)
    plt.plot(sensor_values2[sensor], label='Small', alpha=0.6)
    plt.xlabel('Iteration')
    plt.ylabel('Rotation Value (Sensor Value)')
    plt.title(f'{sensor} Sensor Data')
    plt.legend()

plt.suptitle('Large vs. Small Left SideSteps Sensor Data')

# Adjust layout to avoid overlapping titles
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-R-LAR-60BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-R-SML-60BPM.xlsx'

ITERATION_SIZE = 1000

ITERATION_SIZE = 700

df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)

df = df.head(ITERATION_SIZE)
df2 = df2.head(ITERATION_SIZE)

# Get the sensor values from the DataFrame
sensor_values1 = df[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]
sensor_values2 = df2[['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']]

# Create a 2x2 subplot
plt.figure(figsize=(figure_size_width, figure_size_height))

# Loop through each sensor and plot its data from sensor_values1 and sensor_values2
sensors = ['L_Pitch', 'L_Roll', 'R_Pitch', 'R_Roll']
for i, sensor in enumerate(sensors, 1):
    plt.subplot(2, 2, i)
    plt.plot(sensor_values1[sensor], label='Large', alpha=0.6)
    plt.plot(sensor_values2[sensor], label='Small', alpha=0.6)
    plt.xlabel('Iteration')
    plt.ylabel('Rotation Value (Sensor Value)')
    plt.title(f'{sensor} Sensor Data')
    plt.legend()

plt.suptitle('Large vs. Small Right SideSteps Sensor Data')

# Adjust layout to avoid overlapping titles
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_name = 'C:\\Dev\\vr-kat-project-python-2\\NeuralNetwork\\np-saved-data\\training\\ALL-X-TRAIN-CLASSIFY-MOTIONSPEED-LAR-STEPS-V0.npy'
file_name2 = 'C:\\Dev\\vr-kat-project-python-2\\NeuralNetwork\\np-saved-data\\training\\ALL-Y-TRAIN-CLASSIFY-MOTIONSPEED-LAR-STEPS-V0.npy'

ALL_X_DATA = np.load(file_name)
ALL_Y_DATA = np.load(file_name2)

SUM_X_DATA = np.sum(ALL_X_DATA[:, [0, 2]], axis=1)

print(SUM_X_DATA.shape)
print(ALL_Y_DATA.shape)

# Example data: Replace these with your actual input and class arrays
input_data = np.copy(SUM_X_DATA)
class_labels = np.copy(ALL_Y_DATA)

# Dictionary to store data for each class
class_data = {}
for label in np.unique(class_labels):
    class_data[label] = input_data[class_labels == label]

# Box plot
plt.figure(figsize=(5, 4))
plt.boxplot([class_data[label] for label in np.unique(class_labels)],
            labels=np.unique(class_labels),
            patch_artist=True,
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='black'))
plt.xlabel("")
plt.ylabel("Input Data")
plt.title("Box Plot of Input Data for Different Classes")
plt.grid(True)
plt.show()
# Out:
# (118312,)
# (118312,)

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-LAR-60BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-LAR-120BPM-AUGMENT.xlsx'
file_name3 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-STEPS-LR-LAR-30BPM-AUGMENT.xlsx'

ITERATION_SIZE = 250


df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)
df3 = pd.read_excel(file_name3)

df = df.head(ITERATION_SIZE)
df2 = df2.head(ITERATION_SIZE)
df3 = df3.head(ITERATION_SIZE)

# Get the sensor values from the DataFrame
sensor_values1 = df[['L_Pitch']]
sensor_values2 = df2[['L_Pitch']]
sensor_values3 = df3[['L_Pitch']]

# Create a 2x2 subplot
plt.figure(figsize=(5, 6))

# Loop through each sensor and plot its data from sensor_values1 and sensor_values2
sensors = ['L_Pitch']
for i, sensor in enumerate(sensors, 1):
    plt.subplot(2, 1, i)
    plt.plot(sensor_values1[sensor], label='60BPM', alpha=0.6)
    plt.plot(sensor_values2[sensor], label='120BPM', alpha=0.6)
    plt.plot(sensor_values3[sensor], label='30BPM', alpha=0.6)
    plt.xlabel('Iteration')
    plt.ylabel('Rotation Value (Sensor Value)')
    plt.title(f'{sensor} Sensor Data')
    plt.legend()

# Adjust layout to avoid overlapping titles
plt.tight_layout()

# Show the plot
plt.show()
