# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-L-LAR-80BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\\TRAIN2\\PROC-TRAIN2-SIDESTEPS-L-MED-80BPM.xlsx'


df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)

df = df.head(300)
df2 = df2.head(300)

# Get the sensor values from the DataFrame
sensor_values = df['L_Roll']
sensor_values2 = df2['L_Roll']

# Plot the sensor data with detected peaks
plt.plot(sensor_values, label='large')
plt.plot(sensor_values2, label='medium')
#plt.plot(peaks, sensor_values[peaks], 'ro')
plt.xlabel('Iteration')
plt.ylabel('Sensor Value')
plt.title('Sensor Data and Cycles')
plt.legend()
plt.show()
