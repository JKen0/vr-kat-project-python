# %%
import os
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

# %%
file_name = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\TRAIN2\PROC-TRAIN2-STEPS-LR-LAR-60BPM.xlsx'
file_name2 = 'C:\Dev\\vr-kat-project-python-2\processed-training-data\\4-PROCESSED-DATA\TRAIN2\PROC-TRAIN2-STEPS-LR-MED-60BPM.xlsx'


df = pd.read_excel(file_name)  # Load each Excel file
df2 = pd.read_excel(file_name2)

df = df.head(600)
df2 = df2.head(600)

# Get the sensor values from the DataFrame
sensor_values = df['R_Pitch']
sensor_values2 = df2['R_Pitch']

# Apply peak detection to identify peaks
#peaks, _ = find_peaks(sensor_values, distance=50, prominence=0.1)

# Plot the sensor data with detected peaks
plt.plot(sensor_values)
plt.plot(sensor_values2)
#plt.plot(peaks, sensor_values[peaks], 'ro')
plt.xlabel('Iteration')
plt.ylabel('Sensor Value')
plt.title('Sensor Data and Cycles')
plt.show()
